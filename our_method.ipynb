# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
import numpy as np
import matplotlib.pyplot as plt

# 데이터 디렉토리 경로
data_dir = "/home/iai/Desktop/son/deeplearningproject/결과"

# 랜덤 시드 고정
random_seed = 42
tf.random.set_seed(random_seed)
np.random.seed(random_seed)

# 데이터 로드
batch_size = 32
img_height = 28
img_width = 28

dataset = image_dataset_from_directory(
    data_dir,
    image_size=(img_height, img_width),
    label_mode='categorical',  # 레이블을 원-핫 인코딩 형식으로 반환
    batch_size=batch_size
)

# 클래스 비율 확인
class_names = dataset.class_names
print(f"Class names: {class_names}")

class_counts = np.zeros(len(class_names))
for _, labels in dataset:
    class_counts += np.sum(labels.numpy(), axis=0)

print(f"Class distribution: {class_counts}")

# 데이터셋에서 이미지 shape 확인
for images, labels in dataset.take(1):
    print(f"Image batch shape: {images.shape}")
    print(f"Label batch shape: {labels.shape}")
    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[np.argmax(labels[i])])
        plt.axis("off")
    plt.show()
from sklearn.model_selection import train_test_split
# 데이터셋을 numpy array로 변환
def dataset_to_numpy(dataset):
    images = []
    labels = []
    for img_batch, label_batch in dataset:
        images.append(img_batch.numpy())
        labels.append(label_batch.numpy())
    return np.concatenate(images), np.concatenate(labels)

images, labels = dataset_to_numpy(dataset)

# 데이터셋을 3:1:1 비율로 나누기
train_images, temp_images, train_labels, temp_labels = train_test_split(
    images, labels, test_size=0.4, stratify=labels, random_state=random_seed)

val_images, test_images, val_labels, test_labels = train_test_split(
    temp_images, temp_labels, test_size=0.5, stratify=temp_labels, random_state=random_seed)

# numpy array를 tf.data.Dataset으로 변환
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels)).batch(batch_size)
val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_labels)).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels)).batch(batch_size)

# 각 데이터셋의 클래스 비율 확인
def get_class_distribution(labels):
    class_counts = np.sum(labels, axis=0)
    return class_counts

print(f"Train class distribution: {get_class_distribution(train_labels)}")
print(f"Validation class distribution: {get_class_distribution(val_labels)}")
print(f"Test class distribution: {get_class_distribution(test_labels)}")

# 데이터셋에서 이미지 shape 확인
for images, labels in train_dataset.take(1):
    print(f"Train Image batch shape: {images.shape}")
    print(f"Train Label batch shape: {labels.shape}")
    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[np.argmax(labels[i])])
        plt.axis("off")
    plt.show()

for images, labels in val_dataset.take(1):
    print(f"Validation Image batch shape: {images.shape}")
    print(f"Validation Label batch shape: {labels.shape}")

for images, labels in test_dataset.take(1):
    print(f"Test Image batch shape: {images.shape}")
    print(f"Test Label batch shape: {labels.shape}")
# Out:
# Found 8135 files belonging to 2 classes.
# Class names: ['언어+뇌신경장애', '청각+뇌신경장애']
# Class distribution: [1572. 6563.]
# Image batch shape: (32, 28, 28, 3)
# Label batch shape: (32, 2)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50616 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0, flags=flags)
# Train class distribution: [ 943. 3938.]
# Validation class distribution: [ 315. 1312.]
# Test class distribution: [ 314. 1313.]
# Train Image batch shape: (32, 28, 28, 3)
# Train Label batch shape: (32, 2)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 45516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 49888 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50528 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 45516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 49888 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50528 missing from current font.
#   font.set_text(s, 0, flags=flags)
# Validation Image batch shape: (32, 28, 28, 3)
# Validation Label batch shape: (32, 2)
# Test Image batch shape: (32, 28, 28, 3)
# Test Label batch shape: (32, 2)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import classification_report
import numpy as np
import matplotlib.pyplot as plt
import os

checkpoint_dir = "/home/iai/Desktop/son/deeplearningproject/best_model"

# 모델 정의
def create_baseline1_model():
    model = models.Sequential([
        layers.InputLayer(input_shape=(28, 28, 3)),
        layers.Conv2D(8, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.AveragePooling2D((2, 2)),

        layers.Conv2D(16, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.AveragePooling2D((2, 2)),

        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.AveragePooling2D((2, 2)),

        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.Dense(512, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(2, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# VGG 모델 정의
def create_vgg_model():
    model = models.Sequential([
        layers.InputLayer(input_shape=(28, 28, 3)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),

        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.Dense(512, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(2, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# DenseNet 모델 정의
def create_densenet_model():
    def dense_block(x, blocks, growth_rate):
        for _ in range(blocks):
            x = conv_block(x, growth_rate)
        return x

    def conv_block(x, growth_rate):
        x1 = layers.BatchNormalization()(x)
        x1 = layers.ReLU()(x1)
        x1 = layers.Conv2D(4 * growth_rate, (1, 1), use_bias=False)(x1)
        x1 = layers.BatchNormalization()(x1)
        x1 = layers.ReLU()(x1)
        x1 = layers.Conv2D(growth_rate, (3, 3), padding='same', use_bias=False)(x1)
        x = layers.Concatenate()([x, x1])
        return x

    def transition_block(x, reduction):
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)
        x = layers.Conv2D(int(x.shape[-1] * reduction), (1, 1), use_bias=False)(x)
        x = layers.AveragePooling2D((2, 2), strides=2)(x)
        return x

    inputs = layers.Input(shape=(28, 28, 3))
    x = layers.Conv2D(64, (3, 3), padding='same', use_bias=False)(inputs)
    x = dense_block(x, blocks=4, growth_rate=12)
    x = transition_block(x, reduction=0.5)
    x = dense_block(x, blocks=4, growth_rate=12)
    x = transition_block(x, reduction=0.5)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(2, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model



def train_and_evaluate_model(model, train_dataset, val_dataset, test_dataset):
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=0.00001)
    checkpoint_path_ensemble = os.path.join(checkpoint_dir, "best_model_ensemble.h5")
    checkpoint_ensemble = tf.keras.callbacks.ModelCheckpoint(checkpoint_path_ensemble, monitor='val_loss', save_best_only=True, mode='min')

    history = model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=100,
        batch_size=20,
        callbacks=[checkpoint_ensemble,reduce_lr],
        verbose=1
    )

    model.load_weights(checkpoint_path_ensemble)

    loss, accuracy = model.evaluate(test_dataset)
    print(f"Test loss: {loss}")
    print(f"Test accuracy: {accuracy}")

    y_true = np.concatenate([y for x, y in test_dataset], axis=0)
    y_pred = model.predict(test_dataset)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_true, axis=1)

    report = classification_report(y_true_classes, y_pred_classes, target_names=class_names, output_dict=True)
    return history, report, y_pred, y_true_classes

def calculate_ece(y_true, y_prob, n_bins=10):
    bins = np.linspace(0.0, 1.0, n_bins + 1)
    bin_indices = np.digitize(np.max(y_prob, axis=1), bins) - 1
    ece = 0.0
    for i in range(n_bins):
        bin_mask = bin_indices == i
        bin_size = np.sum(bin_mask)
        if bin_size > 0:
            bin_accuracy = np.mean(y_true[bin_mask] == np.argmax(y_prob[bin_mask], axis=1))
            bin_confidence = np.mean(np.max(y_prob[bin_mask], axis=1))
            ece += np.abs(bin_accuracy - bin_confidence) * bin_size / len(y_true)
    return ece

def calculate_oe(y_true, y_prob, n_bins=10):
    bins = np.linspace(0.0, 1.0, n_bins + 1)
    bin_indices = np.digitize(np.max(y_prob, axis=1), bins) - 1
    oe = 0.0
    for i in range(n_bins):
        bin_mask = bin_indices == i
        bin_size = np.sum(bin_mask)
        if bin_size > 0:
            bin_accuracy = np.mean(y_true[bin_mask] == np.argmax(y_prob[bin_mask], axis=1))
            bin_confidence = np.mean(np.max(y_prob[bin_mask], axis=1))
            if bin_confidence > bin_accuracy:
                oe += (bin_confidence - bin_accuracy) * bin_size / len(y_true)
    return oe

# 모델 1 (Baseline1)
model1 = create_baseline1_model()
history1, report1, y_pred1, y_true_classes = train_and_evaluate_model(model1, train_dataset, val_dataset, test_dataset)

# 모델 2 (VGG)
model2 = create_vgg_model()
history2, report2, y_pred2, _ = train_and_evaluate_model(model2, train_dataset, val_dataset, test_dataset)

# 모델 3 (DenseNet)
model3 = create_densenet_model()
history3, report3, y_pred3, _ = train_and_evaluate_model(model3, train_dataset, val_dataset, test_dataset)

# 앙상블 예측
y_pred_ensemble = (y_pred1 + y_pred2 + y_pred3) / 3
y_pred_classes_ensemble = np.argmax(y_pred_ensemble, axis=1)

# 앙상블 분류 보고서 생성
report_ensemble = classification_report(y_true_classes, y_pred_classes_ensemble, target_names=class_names, output_dict=True)
accuracy_ensemble = report_ensemble['accuracy']
recall_ensemble = report_ensemble['weighted avg']['recall']
precision_ensemble = report_ensemble['weighted avg']['precision']
f1_score_ensemble = report_ensemble['weighted avg']['f1-score']

print(f"Ensemble Accuracy: {accuracy_ensemble}")
print(f"Ensemble Recall: {recall_ensemble}")
print(f"Ensemble Precision: {precision_ensemble}")
print(f"Ensemble F1-score: {f1_score_ensemble}")

# ECE와 OE 계산
ece_ensemble = calculate_ece(y_true_classes, y_pred_ensemble)
oe_ensemble = calculate_oe(y_true_classes, y_pred_ensemble)

print(f"Ensemble ECE: {ece_ensemble}")
print(f"Ensemble OE: {oe_ensemble}")

# 학습 과정 시각화
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history1.history['loss'], label='Baseline1 Train Loss')
plt.plot(history1.history['val_loss'], label='Baseline1 Valid Loss')
plt.plot(history2.history['loss'], label='VGG-like Train Loss')
plt.plot(history2.history['val_loss'], label='VGG-like Valid Loss')
plt.plot(history3.history['loss'], label='DenseNet-like Train Loss')
plt.plot(history3.history['val_loss'], label='DenseNet-like Valid Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history1.history['accuracy'], label='Baseline1 Train Accuracy')
plt.plot(history1.history['val_accuracy'], label='Baseline1 Valid Accuracy')
plt.plot(history2.history['accuracy'], label='VGG-like Train Accuracy')
plt.plot(history2.history['val_accuracy'], label='VGG-like Valid Accuracy')
plt.plot(history3.history['accuracy'], label='DenseNet-like Train Accuracy')
plt.plot(history3.history['val_accuracy'], label='DenseNet-like Valid Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# Epoch 1/100
# 2024-05-23 23:21:41.356498: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2024-05-23 23:21:41.646126: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8101
# 2024-05-23 23:21:42.017662: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
#  26/153 [====>.........................] - ETA: 0s - loss: 0.5128 - accuracy: 0.7861
# 2024-05-23 23:21:42.238647: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2024-05-23 23:21:42.267972: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 153/153 [==============================] - 2s 3ms/step - loss: 0.4639 - accuracy: 0.8080 - val_loss: 0.5208 - val_accuracy: 0.8242
# Epoch 2/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3572 - accuracy: 0.8498 - val_loss: 0.3465 - val_accuracy: 0.8636
# Epoch 3/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.2803 - accuracy: 0.8867 - val_loss: 0.3410 - val_accuracy: 0.8586
# Epoch 4/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.2328 - accuracy: 0.9078 - val_loss: 0.2749 - val_accuracy: 0.9035
# Epoch 5/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.1828 - accuracy: 0.9275 - val_loss: 0.3529 - val_accuracy: 0.8937
# Epoch 6/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.1566 - accuracy: 0.9369 - val_loss: 0.3381 - val_accuracy: 0.9090
# Epoch 7/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.1365 - accuracy: 0.9463 - val_loss: 0.3104 - val_accuracy: 0.9066
# Epoch 8/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.1246 - accuracy: 0.9506 - val_loss: 0.2234 - val_accuracy: 0.9232
# Epoch 9/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.1162 - accuracy: 0.9521 - val_loss: 0.2727 - val_accuracy: 0.9262
# Epoch 10/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.1025 - accuracy: 0.9574 - val_loss: 0.2614 - val_accuracy: 0.9250
# Epoch 11/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.1000 - accuracy: 0.9617 - val_loss: 0.4537 - val_accuracy: 0.8771
# Epoch 12/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0945 - accuracy: 0.9625 - val_loss: 0.3033 - val_accuracy: 0.9164
# Epoch 13/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0869 - accuracy: 0.9641 - val_loss: 0.3175 - val_accuracy: 0.9256
# Epoch 14/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0786 - accuracy: 0.9658 - val_loss: 0.3020 - val_accuracy: 0.9281
# Epoch 15/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0867 - accuracy: 0.9646 - val_loss: 0.4406 - val_accuracy: 0.8906
# Epoch 16/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 0.9687 - val_loss: 0.4485 - val_accuracy: 0.9170
# Epoch 17/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0843 - accuracy: 0.9658 - val_loss: 0.2632 - val_accuracy: 0.9336
# Epoch 18/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0628 - accuracy: 0.9725 - val_loss: 0.3090 - val_accuracy: 0.9312
# Epoch 19/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0535 - accuracy: 0.9766 - val_loss: 0.3024 - val_accuracy: 0.9348
# Epoch 20/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0506 - accuracy: 0.9783 - val_loss: 0.3108 - val_accuracy: 0.9324
# Epoch 21/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0488 - accuracy: 0.9791 - val_loss: 0.3198 - val_accuracy: 0.9312
# Epoch 22/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0475 - accuracy: 0.9793 - val_loss: 0.3283 - val_accuracy: 0.9299
# Epoch 23/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0463 - accuracy: 0.9803 - val_loss: 0.3371 - val_accuracy: 0.9312
# Epoch 24/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9799 - val_loss: 0.3471 - val_accuracy: 0.9312
# Epoch 25/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9801 - val_loss: 0.3576 - val_accuracy: 0.9305
# Epoch 26/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 0.9807 - val_loss: 0.3658 - val_accuracy: 0.9287
# Epoch 27/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 0.9812 - val_loss: 0.3766 - val_accuracy: 0.9287
# Epoch 28/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0396 - accuracy: 0.9820 - val_loss: 0.3864 - val_accuracy: 0.9281
# Epoch 29/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9826 - val_loss: 0.3906 - val_accuracy: 0.9262
# Epoch 30/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 0.9826 - val_loss: 0.3941 - val_accuracy: 0.9262
# Epoch 31/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0360 - accuracy: 0.9828 - val_loss: 0.3965 - val_accuracy: 0.9262
# Epoch 32/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0357 - accuracy: 0.9826 - val_loss: 0.3986 - val_accuracy: 0.9262
# Epoch 33/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 0.9826 - val_loss: 0.4009 - val_accuracy: 0.9262
# Epoch 34/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9828 - val_loss: 0.4032 - val_accuracy: 0.9269
# Epoch 35/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 0.9832 - val_loss: 0.4052 - val_accuracy: 0.9269
# Epoch 36/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0347 - accuracy: 0.9836 - val_loss: 0.4074 - val_accuracy: 0.9269
# Epoch 37/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 0.9836 - val_loss: 0.4098 - val_accuracy: 0.9262
# Epoch 38/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 0.9842 - val_loss: 0.4122 - val_accuracy: 0.9262
# Epoch 39/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 0.9844 - val_loss: 0.4146 - val_accuracy: 0.9262
# Epoch 40/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0337 - accuracy: 0.9846 - val_loss: 0.4171 - val_accuracy: 0.9256
# Epoch 41/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 0.9848 - val_loss: 0.4196 - val_accuracy: 0.9262
# Epoch 42/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 0.9850 - val_loss: 0.4222 - val_accuracy: 0.9262
# Epoch 43/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9850 - val_loss: 0.4251 - val_accuracy: 0.9262
# Epoch 44/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0327 - accuracy: 0.9852 - val_loss: 0.4279 - val_accuracy: 0.9262
# Epoch 45/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0325 - accuracy: 0.9855 - val_loss: 0.4307 - val_accuracy: 0.9256
# Epoch 46/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0322 - accuracy: 0.9855 - val_loss: 0.4338 - val_accuracy: 0.9250
# Epoch 47/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0319 - accuracy: 0.9857 - val_loss: 0.4368 - val_accuracy: 0.9256
# Epoch 48/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 0.9859 - val_loss: 0.4399 - val_accuracy: 0.9262
# Epoch 49/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 0.9861 - val_loss: 0.4431 - val_accuracy: 0.9262
# Epoch 50/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0312 - accuracy: 0.9863 - val_loss: 0.4462 - val_accuracy: 0.9269
# Epoch 51/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0309 - accuracy: 0.9867 - val_loss: 0.4493 - val_accuracy: 0.9269
# Epoch 52/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 0.9867 - val_loss: 0.4525 - val_accuracy: 0.9275
# Epoch 53/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 0.9867 - val_loss: 0.4557 - val_accuracy: 0.9275
# Epoch 54/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 0.9869 - val_loss: 0.4591 - val_accuracy: 0.9275
# Epoch 55/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 0.9867 - val_loss: 0.4627 - val_accuracy: 0.9275
# Epoch 56/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 0.9867 - val_loss: 0.4662 - val_accuracy: 0.9281
# Epoch 57/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0291 - accuracy: 0.9869 - val_loss: 0.4697 - val_accuracy: 0.9281
# Epoch 58/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9875 - val_loss: 0.4736 - val_accuracy: 0.9287
# Epoch 59/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 0.9875 - val_loss: 0.4773 - val_accuracy: 0.9287
# Epoch 60/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0282 - accuracy: 0.9877 - val_loss: 0.4810 - val_accuracy: 0.9287
# Epoch 61/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0279 - accuracy: 0.9879 - val_loss: 0.4848 - val_accuracy: 0.9287
# Epoch 62/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 0.9879 - val_loss: 0.4887 - val_accuracy: 0.9287
# Epoch 63/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0273 - accuracy: 0.9883 - val_loss: 0.4926 - val_accuracy: 0.9287
# Epoch 64/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9887 - val_loss: 0.4965 - val_accuracy: 0.9275
# Epoch 65/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0266 - accuracy: 0.9889 - val_loss: 0.5005 - val_accuracy: 0.9275
# Epoch 66/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0263 - accuracy: 0.9889 - val_loss: 0.5045 - val_accuracy: 0.9269
# Epoch 67/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9891 - val_loss: 0.5084 - val_accuracy: 0.9269
# Epoch 68/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 0.9893 - val_loss: 0.5126 - val_accuracy: 0.9269
# Epoch 69/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0254 - accuracy: 0.9893 - val_loss: 0.5171 - val_accuracy: 0.9262
# Epoch 70/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 0.9891 - val_loss: 0.5211 - val_accuracy: 0.9262
# Epoch 71/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 0.9891 - val_loss: 0.5254 - val_accuracy: 0.9256
# Epoch 72/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9896 - val_loss: 0.5296 - val_accuracy: 0.9250
# Epoch 73/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.9900 - val_loss: 0.5338 - val_accuracy: 0.9256
# Epoch 74/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0239 - accuracy: 0.9900 - val_loss: 0.5382 - val_accuracy: 0.9256
# Epoch 75/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 0.9902 - val_loss: 0.5423 - val_accuracy: 0.9256
# Epoch 76/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 0.9906 - val_loss: 0.5468 - val_accuracy: 0.9256
# Epoch 77/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 0.9912 - val_loss: 0.5514 - val_accuracy: 0.9256
# Epoch 78/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 0.9912 - val_loss: 0.5558 - val_accuracy: 0.9256
# Epoch 79/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 0.9912 - val_loss: 0.5604 - val_accuracy: 0.9256
# Epoch 80/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0222 - accuracy: 0.9916 - val_loss: 0.5650 - val_accuracy: 0.9256
# Epoch 81/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 0.9920 - val_loss: 0.5700 - val_accuracy: 0.9256
# Epoch 82/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 0.9920 - val_loss: 0.5745 - val_accuracy: 0.9256
# Epoch 83/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0214 - accuracy: 0.9922 - val_loss: 0.5794 - val_accuracy: 0.9256
# Epoch 84/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 0.9922 - val_loss: 0.5840 - val_accuracy: 0.9256
# Epoch 85/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 0.9922 - val_loss: 0.5887 - val_accuracy: 0.9256
# Epoch 86/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9924 - val_loss: 0.5938 - val_accuracy: 0.9256
# Epoch 87/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 0.9926 - val_loss: 0.5988 - val_accuracy: 0.9256
# Epoch 88/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9924 - val_loss: 0.6038 - val_accuracy: 0.9250
# Epoch 89/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9924 - val_loss: 0.6088 - val_accuracy: 0.9250
# Epoch 90/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 0.9932 - val_loss: 0.6132 - val_accuracy: 0.9250
# Epoch 91/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 0.9930 - val_loss: 0.6185 - val_accuracy: 0.9250
# Epoch 92/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9934 - val_loss: 0.6234 - val_accuracy: 0.9250
# Epoch 93/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 0.9934 - val_loss: 0.6283 - val_accuracy: 0.9250
# Epoch 94/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.6332 - val_accuracy: 0.9256
# Epoch 95/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 0.9939 - val_loss: 0.6383 - val_accuracy: 0.9256
# Epoch 96/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9941 - val_loss: 0.6431 - val_accuracy: 0.9256
# Epoch 97/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.9941 - val_loss: 0.6481 - val_accuracy: 0.9256
# Epoch 98/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9941 - val_loss: 0.6529 - val_accuracy: 0.9256
# Epoch 99/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9945 - val_loss: 0.6577 - val_accuracy: 0.9256
# Epoch 100/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 0.9943 - val_loss: 0.6624 - val_accuracy: 0.9256
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2158 - accuracy: 0.9330
# Test loss: 0.2158135622739792
# Test accuracy: 0.9330055117607117
# Epoch 1/100
# 153/153 [==============================] - 1s 4ms/step - loss: 0.6272 - accuracy: 0.7972 - val_loss: 0.4255 - val_accuracy: 0.8119
# Epoch 2/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3945 - accuracy: 0.8324 - val_loss: 0.3892 - val_accuracy: 0.8187
# Epoch 3/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3244 - accuracy: 0.8666 - val_loss: 0.2923 - val_accuracy: 0.8838
# Epoch 4/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.2631 - accuracy: 0.8908 - val_loss: 0.2708 - val_accuracy: 0.8912
# Epoch 5/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.2107 - accuracy: 0.9154 - val_loss: 0.2920 - val_accuracy: 0.9084
# Epoch 6/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1887 - accuracy: 0.9262 - val_loss: 0.3568 - val_accuracy: 0.8832
# Epoch 7/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1759 - accuracy: 0.9295 - val_loss: 0.2259 - val_accuracy: 0.9189
# Epoch 8/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1442 - accuracy: 0.9445 - val_loss: 0.2788 - val_accuracy: 0.9078
# Epoch 9/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1502 - accuracy: 0.9400 - val_loss: 0.2259 - val_accuracy: 0.9189
# Epoch 10/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1434 - accuracy: 0.9441 - val_loss: 0.2876 - val_accuracy: 0.9201
# Epoch 11/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1135 - accuracy: 0.9510 - val_loss: 0.3120 - val_accuracy: 0.9140
# Epoch 12/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1027 - accuracy: 0.9553 - val_loss: 0.3037 - val_accuracy: 0.9152
# Epoch 13/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0865 - accuracy: 0.9637 - val_loss: 0.2815 - val_accuracy: 0.9207
# Epoch 14/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0911 - accuracy: 0.9603 - val_loss: 0.4605 - val_accuracy: 0.9195
# Epoch 15/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0891 - accuracy: 0.9633 - val_loss: 0.3296 - val_accuracy: 0.9238
# Epoch 16/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0697 - accuracy: 0.9707 - val_loss: 0.3667 - val_accuracy: 0.9140
# Epoch 17/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1054 - accuracy: 0.9586 - val_loss: 0.2925 - val_accuracy: 0.9207
# Epoch 18/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0518 - accuracy: 0.9793 - val_loss: 0.2827 - val_accuracy: 0.9305
# Epoch 19/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0265 - accuracy: 0.9900 - val_loss: 0.3476 - val_accuracy: 0.9238
# Epoch 20/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 0.9928 - val_loss: 0.4126 - val_accuracy: 0.9244
# Epoch 21/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 0.9941 - val_loss: 0.4727 - val_accuracy: 0.9244
# Epoch 22/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 0.9953 - val_loss: 0.5333 - val_accuracy: 0.9250
# Epoch 23/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 0.9965 - val_loss: 0.5854 - val_accuracy: 0.9256
# Epoch 24/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 0.9971 - val_loss: 0.6365 - val_accuracy: 0.9244
# Epoch 25/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.6897 - val_accuracy: 0.9256
# Epoch 26/100
# 153/153 [==============================] - 1s 4ms/step - loss: 0.0049 - accuracy: 0.9982 - val_loss: 0.7352 - val_accuracy: 0.9256
# Epoch 27/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.7737 - val_accuracy: 0.9250
# Epoch 28/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.7798 - val_accuracy: 0.9244
# Epoch 29/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.7852 - val_accuracy: 0.9244
# Epoch 30/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.7906 - val_accuracy: 0.9244
# Epoch 31/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.7960 - val_accuracy: 0.9244
# Epoch 32/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.8012 - val_accuracy: 0.9244
# Epoch 33/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.8065 - val_accuracy: 0.9244
# Epoch 34/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.8116 - val_accuracy: 0.9244
# Epoch 35/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.8170 - val_accuracy: 0.9244
# Epoch 36/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.8222 - val_accuracy: 0.9244
# Epoch 37/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.8279 - val_accuracy: 0.9244
# Epoch 38/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.8337 - val_accuracy: 0.9244
# Epoch 39/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.8393 - val_accuracy: 0.9238
# Epoch 40/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.8454 - val_accuracy: 0.9238
# Epoch 41/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.8512 - val_accuracy: 0.9238
# Epoch 42/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.8577 - val_accuracy: 0.9238
# Epoch 43/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.8636 - val_accuracy: 0.9238
# Epoch 44/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.8701 - val_accuracy: 0.9238
# Epoch 45/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.8764 - val_accuracy: 0.9238
# Epoch 46/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.8833 - val_accuracy: 0.9238
# Epoch 47/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.8896 - val_accuracy: 0.9238
# Epoch 48/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.8966 - val_accuracy: 0.9238
# Epoch 49/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.9034 - val_accuracy: 0.9238
# Epoch 50/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.9100 - val_accuracy: 0.9238
# Epoch 51/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.9175 - val_accuracy: 0.9232
# Epoch 52/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.9242 - val_accuracy: 0.9232
# Epoch 53/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.9317 - val_accuracy: 0.9232
# Epoch 54/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.9391 - val_accuracy: 0.9232
# Epoch 55/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9468 - val_accuracy: 0.9232
# Epoch 56/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9546 - val_accuracy: 0.9232
# Epoch 57/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9626 - val_accuracy: 0.9232
# Epoch 58/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9705 - val_accuracy: 0.9232
# Epoch 59/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9744 - val_accuracy: 0.9232
# Epoch 60/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9834 - val_accuracy: 0.9232
# Epoch 61/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9927 - val_accuracy: 0.9232
# Epoch 62/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0023 - val_accuracy: 0.9238
# Epoch 63/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0117 - val_accuracy: 0.9238
# Epoch 64/100
# 153/153 [==============================] - 1s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0201 - val_accuracy: 0.9238
# Epoch 65/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0288 - val_accuracy: 0.9238
# Epoch 66/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0386 - val_accuracy: 0.9232
# Epoch 67/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.0458 - val_accuracy: 0.9238
# Epoch 68/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0485 - val_accuracy: 0.9232
# Epoch 69/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0584 - val_accuracy: 0.9232
# Epoch 70/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.0692 - val_accuracy: 0.9232
# Epoch 71/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.0784 - val_accuracy: 0.9232
# Epoch 72/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.0885 - val_accuracy: 0.9232
# Epoch 73/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.0986 - val_accuracy: 0.9232
# Epoch 74/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1085 - val_accuracy: 0.9232
# Epoch 75/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1183 - val_accuracy: 0.9238
# Epoch 76/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1263 - val_accuracy: 0.9238
# Epoch 77/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1362 - val_accuracy: 0.9238
# Epoch 78/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1464 - val_accuracy: 0.9238
# Epoch 79/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1558 - val_accuracy: 0.9238
# Epoch 80/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1660 - val_accuracy: 0.9238
# Epoch 81/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1751 - val_accuracy: 0.9238
# Epoch 82/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1779 - val_accuracy: 0.9238
# Epoch 83/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9984 - val_loss: 1.1731 - val_accuracy: 0.9226
# Epoch 84/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1851 - val_accuracy: 0.9238
# Epoch 85/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1977 - val_accuracy: 0.9238
# Epoch 86/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2096 - val_accuracy: 0.9238
# Epoch 87/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2211 - val_accuracy: 0.9244
# Epoch 88/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2326 - val_accuracy: 0.9244
# Epoch 89/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2435 - val_accuracy: 0.9244
# Epoch 90/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2543 - val_accuracy: 0.9250
# Epoch 91/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2655 - val_accuracy: 0.9244
# Epoch 92/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2764 - val_accuracy: 0.9250
# Epoch 93/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2872 - val_accuracy: 0.9250
# Epoch 94/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2985 - val_accuracy: 0.9244
# Epoch 95/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.3076 - val_accuracy: 0.9244
# Epoch 96/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.3186 - val_accuracy: 0.9250
# Epoch 97/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 0.9986 - val_loss: 1.3298 - val_accuracy: 0.9250
# Epoch 98/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 0.9986 - val_loss: 1.3399 - val_accuracy: 0.9250
# Epoch 99/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 0.9986 - val_loss: 1.3504 - val_accuracy: 0.9250
# Epoch 100/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 0.9986 - val_loss: 1.3598 - val_accuracy: 0.9244
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2348 - accuracy: 0.9109
# Test loss: 0.2347603291273117
# Test accuracy: 0.9108788967132568
# Epoch 1/100
# 153/153 [==============================] - 2s 9ms/step - loss: 0.4778 - accuracy: 0.8060 - val_loss: 0.5509 - val_accuracy: 0.8064
# Epoch 2/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.4210 - accuracy: 0.8283 - val_loss: 0.5425 - val_accuracy: 0.8070
# Epoch 3/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.3756 - accuracy: 0.8478 - val_loss: 0.5089 - val_accuracy: 0.7523
# Epoch 4/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.3307 - accuracy: 0.8687 - val_loss: 0.8474 - val_accuracy: 0.6577
# Epoch 5/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.3008 - accuracy: 0.8830 - val_loss: 0.3978 - val_accuracy: 0.8685
# Epoch 6/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.2722 - accuracy: 0.8951 - val_loss: 1.7533 - val_accuracy: 0.8082
# Epoch 7/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.2512 - accuracy: 0.9025 - val_loss: 0.9064 - val_accuracy: 0.8316
# Epoch 8/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.2168 - accuracy: 0.9111 - val_loss: 0.7713 - val_accuracy: 0.8316
# Epoch 9/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1934 - accuracy: 0.9230 - val_loss: 0.3341 - val_accuracy: 0.8918
# Epoch 10/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1848 - accuracy: 0.9246 - val_loss: 1.3808 - val_accuracy: 0.8175
# Epoch 11/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1722 - accuracy: 0.9303 - val_loss: 0.2660 - val_accuracy: 0.9023
# Epoch 12/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1606 - accuracy: 0.9357 - val_loss: 0.3976 - val_accuracy: 0.8924
# Epoch 13/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1463 - accuracy: 0.9416 - val_loss: 0.2712 - val_accuracy: 0.9158
# Epoch 14/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1458 - accuracy: 0.9416 - val_loss: 0.3054 - val_accuracy: 0.9084
# Epoch 15/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1260 - accuracy: 0.9492 - val_loss: 0.2577 - val_accuracy: 0.9176
# Epoch 16/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1267 - accuracy: 0.9500 - val_loss: 0.2605 - val_accuracy: 0.9232
# Epoch 17/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1189 - accuracy: 0.9531 - val_loss: 0.3501 - val_accuracy: 0.9060
# Epoch 18/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1211 - accuracy: 0.9514 - val_loss: 0.2888 - val_accuracy: 0.9133
# Epoch 19/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1084 - accuracy: 0.9562 - val_loss: 0.4130 - val_accuracy: 0.8943
# Epoch 20/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1111 - accuracy: 0.9560 - val_loss: 0.2265 - val_accuracy: 0.9305
# Epoch 21/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1190 - accuracy: 0.9523 - val_loss: 0.5726 - val_accuracy: 0.8943
# Epoch 22/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1033 - accuracy: 0.9574 - val_loss: 0.4450 - val_accuracy: 0.8881
# Epoch 23/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1016 - accuracy: 0.9574 - val_loss: 0.4461 - val_accuracy: 0.8875
# Epoch 24/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1040 - accuracy: 0.9576 - val_loss: 0.2787 - val_accuracy: 0.9035
# Epoch 25/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0895 - accuracy: 0.9639 - val_loss: 0.3464 - val_accuracy: 0.9066
# Epoch 26/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1256 - accuracy: 0.9525 - val_loss: 0.4817 - val_accuracy: 0.8427
# Epoch 27/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0960 - accuracy: 0.9617 - val_loss: 0.2395 - val_accuracy: 0.9213
# Epoch 28/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0836 - accuracy: 0.9658 - val_loss: 0.6030 - val_accuracy: 0.8537
# Epoch 29/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0890 - accuracy: 0.9633 - val_loss: 0.3064 - val_accuracy: 0.9152
# Epoch 30/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0768 - accuracy: 0.9682 - val_loss: 0.3345 - val_accuracy: 0.9373
# Epoch 31/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0600 - accuracy: 0.9728 - val_loss: 0.2188 - val_accuracy: 0.9447
# Epoch 32/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0537 - accuracy: 0.9762 - val_loss: 0.2365 - val_accuracy: 0.9422
# Epoch 33/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0513 - accuracy: 0.9762 - val_loss: 0.2466 - val_accuracy: 0.9435
# Epoch 34/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0490 - accuracy: 0.9781 - val_loss: 0.2578 - val_accuracy: 0.9435
# Epoch 35/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0466 - accuracy: 0.9793 - val_loss: 0.2572 - val_accuracy: 0.9441
# Epoch 36/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0446 - accuracy: 0.9797 - val_loss: 0.2621 - val_accuracy: 0.9428
# Epoch 37/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0426 - accuracy: 0.9803 - val_loss: 0.2698 - val_accuracy: 0.9441
# Epoch 38/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0410 - accuracy: 0.9809 - val_loss: 0.2761 - val_accuracy: 0.9410
# Epoch 39/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0392 - accuracy: 0.9822 - val_loss: 0.2869 - val_accuracy: 0.9404
# Epoch 40/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0375 - accuracy: 0.9834 - val_loss: 0.2971 - val_accuracy: 0.9392
# Epoch 41/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0358 - accuracy: 0.9838 - val_loss: 0.3055 - val_accuracy: 0.9404
# Epoch 42/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0340 - accuracy: 0.9852 - val_loss: 0.3120 - val_accuracy: 0.9379
# Epoch 43/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0327 - accuracy: 0.9850 - val_loss: 0.3118 - val_accuracy: 0.9379
# Epoch 44/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0324 - accuracy: 0.9852 - val_loss: 0.3126 - val_accuracy: 0.9379
# Epoch 45/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0321 - accuracy: 0.9857 - val_loss: 0.3140 - val_accuracy: 0.9373
# Epoch 46/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0318 - accuracy: 0.9857 - val_loss: 0.3158 - val_accuracy: 0.9373
# Epoch 47/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0315 - accuracy: 0.9859 - val_loss: 0.3175 - val_accuracy: 0.9373
# Epoch 48/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0312 - accuracy: 0.9857 - val_loss: 0.3194 - val_accuracy: 0.9373
# Epoch 49/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0309 - accuracy: 0.9857 - val_loss: 0.3214 - val_accuracy: 0.9373
# Epoch 50/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0306 - accuracy: 0.9857 - val_loss: 0.3233 - val_accuracy: 0.9367
# Epoch 51/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0303 - accuracy: 0.9859 - val_loss: 0.3251 - val_accuracy: 0.9361
# Epoch 52/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0300 - accuracy: 0.9859 - val_loss: 0.3271 - val_accuracy: 0.9361
# Epoch 53/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0297 - accuracy: 0.9861 - val_loss: 0.3290 - val_accuracy: 0.9361
# Epoch 54/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0294 - accuracy: 0.9861 - val_loss: 0.3314 - val_accuracy: 0.9355
# Epoch 55/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0291 - accuracy: 0.9863 - val_loss: 0.3338 - val_accuracy: 0.9355
# Epoch 56/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0288 - accuracy: 0.9867 - val_loss: 0.3363 - val_accuracy: 0.9355
# Epoch 57/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0285 - accuracy: 0.9865 - val_loss: 0.3386 - val_accuracy: 0.9348
# Epoch 58/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0282 - accuracy: 0.9871 - val_loss: 0.3408 - val_accuracy: 0.9348
# Epoch 59/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0279 - accuracy: 0.9873 - val_loss: 0.3435 - val_accuracy: 0.9348
# Epoch 60/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0276 - accuracy: 0.9873 - val_loss: 0.3459 - val_accuracy: 0.9348
# Epoch 61/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0273 - accuracy: 0.9875 - val_loss: 0.3483 - val_accuracy: 0.9342
# Epoch 62/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0271 - accuracy: 0.9875 - val_loss: 0.3506 - val_accuracy: 0.9336
# Epoch 63/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0268 - accuracy: 0.9877 - val_loss: 0.3531 - val_accuracy: 0.9330
# Epoch 64/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0265 - accuracy: 0.9879 - val_loss: 0.3553 - val_accuracy: 0.9330
# Epoch 65/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0262 - accuracy: 0.9881 - val_loss: 0.3580 - val_accuracy: 0.9324
# Epoch 66/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0259 - accuracy: 0.9881 - val_loss: 0.3608 - val_accuracy: 0.9330
# Epoch 67/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0257 - accuracy: 0.9883 - val_loss: 0.3638 - val_accuracy: 0.9336
# Epoch 68/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0254 - accuracy: 0.9883 - val_loss: 0.3663 - val_accuracy: 0.9324
# Epoch 69/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0251 - accuracy: 0.9883 - val_loss: 0.3693 - val_accuracy: 0.9318
# Epoch 70/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0249 - accuracy: 0.9883 - val_loss: 0.3722 - val_accuracy: 0.9318
# Epoch 71/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0246 - accuracy: 0.9883 - val_loss: 0.3755 - val_accuracy: 0.9318
# Epoch 72/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0244 - accuracy: 0.9885 - val_loss: 0.3791 - val_accuracy: 0.9318
# Epoch 73/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0241 - accuracy: 0.9889 - val_loss: 0.3825 - val_accuracy: 0.9305
# Epoch 74/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0238 - accuracy: 0.9891 - val_loss: 0.3860 - val_accuracy: 0.9299
# Epoch 75/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0236 - accuracy: 0.9893 - val_loss: 0.3892 - val_accuracy: 0.9299
# Epoch 76/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0233 - accuracy: 0.9898 - val_loss: 0.3919 - val_accuracy: 0.9299
# Epoch 77/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0231 - accuracy: 0.9898 - val_loss: 0.3952 - val_accuracy: 0.9299
# Epoch 78/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0229 - accuracy: 0.9898 - val_loss: 0.3978 - val_accuracy: 0.9299
# Epoch 79/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0227 - accuracy: 0.9898 - val_loss: 0.4012 - val_accuracy: 0.9299
# Epoch 80/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0225 - accuracy: 0.9898 - val_loss: 0.4042 - val_accuracy: 0.9305
# Epoch 81/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0223 - accuracy: 0.9898 - val_loss: 0.4074 - val_accuracy: 0.9305
# Epoch 82/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0221 - accuracy: 0.9898 - val_loss: 0.4108 - val_accuracy: 0.9305
# Epoch 83/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0219 - accuracy: 0.9898 - val_loss: 0.4141 - val_accuracy: 0.9305
# Epoch 84/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0217 - accuracy: 0.9900 - val_loss: 0.4171 - val_accuracy: 0.9305
# Epoch 85/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0215 - accuracy: 0.9900 - val_loss: 0.4203 - val_accuracy: 0.9305
# Epoch 86/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0213 - accuracy: 0.9900 - val_loss: 0.4238 - val_accuracy: 0.9305
# Epoch 87/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0211 - accuracy: 0.9900 - val_loss: 0.4270 - val_accuracy: 0.9299
# Epoch 88/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0209 - accuracy: 0.9902 - val_loss: 0.4304 - val_accuracy: 0.9299
# Epoch 89/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0207 - accuracy: 0.9902 - val_loss: 0.4340 - val_accuracy: 0.9299
# Epoch 90/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0205 - accuracy: 0.9902 - val_loss: 0.4371 - val_accuracy: 0.9293
# Epoch 91/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0203 - accuracy: 0.9902 - val_loss: 0.4412 - val_accuracy: 0.9293
# Epoch 92/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0201 - accuracy: 0.9902 - val_loss: 0.4448 - val_accuracy: 0.9299
# Epoch 93/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0199 - accuracy: 0.9904 - val_loss: 0.4485 - val_accuracy: 0.9299
# Epoch 94/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0197 - accuracy: 0.9906 - val_loss: 0.4524 - val_accuracy: 0.9312
# Epoch 95/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0194 - accuracy: 0.9906 - val_loss: 0.4563 - val_accuracy: 0.9293
# Epoch 96/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0192 - accuracy: 0.9908 - val_loss: 0.4606 - val_accuracy: 0.9293
# Epoch 97/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0190 - accuracy: 0.9908 - val_loss: 0.4639 - val_accuracy: 0.9287
# Epoch 98/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0188 - accuracy: 0.9908 - val_loss: 0.4678 - val_accuracy: 0.9293
# Epoch 99/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0186 - accuracy: 0.9910 - val_loss: 0.4717 - val_accuracy: 0.9293
# Epoch 100/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0184 - accuracy: 0.9910 - val_loss: 0.4758 - val_accuracy: 0.9299
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2700 - accuracy: 0.9398
# Test loss: 0.269999623298645
# Test accuracy: 0.9397664666175842
# Ensemble Accuracy: 0.9483712354025814
# Ensemble Recall: 0.9483712354025814
# Ensemble Precision: 0.9484070894118084
# Ensemble F1-score: 0.9463023456580201
# Ensemble ECE: 0.02501523022132924
# Ensemble OE: 0.00016892205445255117
