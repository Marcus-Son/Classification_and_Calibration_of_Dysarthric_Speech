# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
import numpy as np
import matplotlib.pyplot as plt

# 데이터 디렉토리 경로
data_dir = "/home/iai/Desktop/son/deeplearningproject/결과"

# 랜덤 시드 고정
random_seed = 42
tf.random.set_seed(random_seed)
np.random.seed(random_seed)

# 데이터 로드
batch_size = 32
img_height = 28
img_width = 28

dataset = image_dataset_from_directory(
    data_dir,
    image_size=(img_height, img_width),
    label_mode='categorical',  # 레이블을 원-핫 인코딩 형식으로 반환
    batch_size=batch_size
)

# 클래스 비율 확인
class_names = dataset.class_names
print(f"Class names: {class_names}")

class_counts = np.zeros(len(class_names))
for _, labels in dataset:
    class_counts += np.sum(labels.numpy(), axis=0)

print(f"Class distribution: {class_counts}")

# 데이터셋에서 이미지 shape 확인
for images, labels in dataset.take(1):
    print(f"Image batch shape: {images.shape}")
    print(f"Label batch shape: {labels.shape}")
    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[np.argmax(labels[i])])
        plt.axis("off")
    plt.show()
from sklearn.model_selection import train_test_split
# 데이터셋을 numpy array로 변환
def dataset_to_numpy(dataset):
    images = []
    labels = []
    for img_batch, label_batch in dataset:
        images.append(img_batch.numpy())
        labels.append(label_batch.numpy())
    return np.concatenate(images), np.concatenate(labels)

images, labels = dataset_to_numpy(dataset)

# 데이터셋을 3:1:1 비율로 나누기
train_images, temp_images, train_labels, temp_labels = train_test_split(
    images, labels, test_size=0.4, stratify=labels, random_state=random_seed)

val_images, test_images, val_labels, test_labels = train_test_split(
    temp_images, temp_labels, test_size=0.5, stratify=temp_labels, random_state=random_seed)

# numpy array를 tf.data.Dataset으로 변환
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels)).batch(batch_size)
val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_labels)).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels)).batch(batch_size)

# 각 데이터셋의 클래스 비율 확인
def get_class_distribution(labels):
    class_counts = np.sum(labels, axis=0)
    return class_counts

print(f"Train class distribution: {get_class_distribution(train_labels)}")
print(f"Validation class distribution: {get_class_distribution(val_labels)}")
print(f"Test class distribution: {get_class_distribution(test_labels)}")

# 데이터셋에서 이미지 shape 확인
for images, labels in train_dataset.take(1):
    print(f"Train Image batch shape: {images.shape}")
    print(f"Train Label batch shape: {labels.shape}")
    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[np.argmax(labels[i])])
        plt.axis("off")
    plt.show()

for images, labels in val_dataset.take(1):
    print(f"Validation Image batch shape: {images.shape}")
    print(f"Validation Label batch shape: {labels.shape}")

for images, labels in test_dataset.take(1):
    print(f"Test Image batch shape: {images.shape}")
    print(f"Test Label batch shape: {labels.shape}")
# Out:
# 2024-05-25 22:12:39.358684: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Found 8135 files belonging to 2 classes.
# 2024-05-25 22:12:39.938031: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2024-05-25 22:12:39.967487: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-25 22:12:39.967567: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.69GiB deviceMemoryBandwidth: 871.81GiB/s
# 2024-05-25 22:12:39.967576: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2024-05-25 22:12:39.968908: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2024-05-25 22:12:39.968925: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2024-05-25 22:12:39.969343: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2024-05-25 22:12:39.969439: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2024-05-25 22:12:39.969781: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2024-05-25 22:12:39.970074: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2024-05-25 22:12:39.970126: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2024-05-25 22:12:39.970159: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-25 22:12:39.970226: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-25 22:12:39.970268: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2024-05-25 22:12:39.970572: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-25 22:12:39.971188: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-25 22:12:39.971245: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.695GHz coreCount: 82 deviceMemorySize: 23.69GiB deviceMemoryBandwidth: 871.81GiB/s
# 2024-05-25 22:12:39.971271: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-25 22:12:39.971323: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-25 22:12:39.971359: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2024-05-25 22:12:39.971371: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2024-05-25 22:12:40.210863: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-05-25 22:12:40.210889: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2024-05-25 22:12:40.210893: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2024-05-25 22:12:40.211039: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-25 22:12:40.211127: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-25 22:12:40.211189: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-05-25 22:12:40.211244: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22312 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6)
# 2024-05-25 22:12:40.345917: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2024-05-25 22:12:40.364044: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 4500240000 Hz
# Class names: ['언어+뇌신경장애', '청각+뇌신경장애']
# Class distribution: [1572. 6563.]
# Image batch shape: (32, 28, 28, 3)
# Label batch shape: (32, 2)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 45516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 49888 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50528 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 45516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 49888 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50528 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50616 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0, flags=flags)
# Train class distribution: [ 943. 3938.]
# Validation class distribution: [ 315. 1312.]
# Test class distribution: [ 314. 1313.]
# Train Image batch shape: (32, 28, 28, 3)
# Train Label batch shape: (32, 2)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 45516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 49888 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50528 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44033 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 45516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 49888 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/iai/anaconda3/envs/deeplearning/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50528 missing from current font.
#   font.set_text(s, 0, flags=flags)
# Validation Image batch shape: (32, 28, 28, 3)
# Validation Label batch shape: (32, 2)
# Test Image batch shape: (32, 28, 28, 3)
# Test Label batch shape: (32, 2)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import classification_report
import numpy as np
import matplotlib.pyplot as plt
import os

checkpoint_dir = "/home/iai/Desktop/son/deeplearningproject/best_model"

# 모델 정의
def create_baseline1_model():
    model = models.Sequential([
        layers.InputLayer(input_shape=(28, 28, 3)),
        layers.Conv2D(8, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.AveragePooling2D((2, 2)),

        layers.Conv2D(16, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.AveragePooling2D((2, 2)),

        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.AveragePooling2D((2, 2)),

        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.Dense(512, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(2, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# VGG 모델 정의
def create_vgg_model():
    model = models.Sequential([
        layers.InputLayer(input_shape=(28, 28, 3)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),

        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.Dense(512, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(2, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# DenseNet 모델 정의
def create_densenet_model():
    def dense_block(x, blocks, growth_rate):
        for _ in range(blocks):
            x = conv_block(x, growth_rate)
        return x

    def conv_block(x, growth_rate):
        x1 = layers.BatchNormalization()(x)
        x1 = layers.ReLU()(x1)
        x1 = layers.Conv2D(4 * growth_rate, (1, 1), use_bias=False)(x1)
        x1 = layers.BatchNormalization()(x1)
        x1 = layers.ReLU()(x1)
        x1 = layers.Conv2D(growth_rate, (3, 3), padding='same', use_bias=False)(x1)
        x = layers.Concatenate()([x, x1])
        return x

    def transition_block(x, reduction):
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)
        x = layers.Conv2D(int(x.shape[-1] * reduction), (1, 1), use_bias=False)(x)
        x = layers.AveragePooling2D((2, 2), strides=2)(x)
        return x

    inputs = layers.Input(shape=(28, 28, 3))
    x = layers.Conv2D(64, (3, 3), padding='same', use_bias=False)(inputs)
    x = dense_block(x, blocks=4, growth_rate=12)
    x = transition_block(x, reduction=0.5)
    x = dense_block(x, blocks=4, growth_rate=12)
    x = transition_block(x, reduction=0.5)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(2, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model



def train_and_evaluate_model(model, train_dataset, val_dataset, test_dataset,model_name):
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=0.00001)
    checkpoint_path_ensemble = os.path.join(checkpoint_dir, f"best_model_ensemble1_{model_name}.h5")
    checkpoint_ensemble = tf.keras.callbacks.ModelCheckpoint(checkpoint_path_ensemble, monitor='val_loss', save_best_only=True, mode='min')

    history = model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=100,
        batch_size=20,
        callbacks=[checkpoint_ensemble,reduce_lr],
        verbose=1
    )

    model.load_weights(checkpoint_path_ensemble)

    loss, accuracy = model.evaluate(test_dataset)
    print(f"Test loss: {loss}")
    print(f"Test accuracy: {accuracy}")

    y_true = np.concatenate([y for x, y in test_dataset], axis=0)
    y_pred = model.predict(test_dataset)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_true, axis=1)

    report = classification_report(y_true_classes, y_pred_classes, target_names=class_names, output_dict=True)
    return history, report, y_pred, y_true_classes

def calculate_ece(y_true, y_prob, n_bins=10):
    bins = np.linspace(0.0, 1.0, n_bins + 1)
    bin_indices = np.digitize(np.max(y_prob, axis=1), bins) - 1
    ece = 0.0
    for i in range(n_bins):
        bin_mask = bin_indices == i
        bin_size = np.sum(bin_mask)
        if bin_size > 0:
            bin_accuracy = np.mean(y_true[bin_mask] == np.argmax(y_prob[bin_mask], axis=1))
            bin_confidence = np.mean(np.max(y_prob[bin_mask], axis=1))
            ece += np.abs(bin_accuracy - bin_confidence) * bin_size / len(y_true)
    return ece

def calculate_oe(y_true, y_prob, n_bins=10):
    bins = np.linspace(0.0, 1.0, n_bins + 1)
    bin_indices = np.digitize(np.max(y_prob, axis=1), bins) - 1
    oe = 0.0
    for i in range(n_bins):
        bin_mask = bin_indices == i
        bin_size = np.sum(bin_mask)
        if bin_size > 0:
            bin_accuracy = np.mean(y_true[bin_mask] == np.argmax(y_prob[bin_mask], axis=1))
            bin_confidence = np.mean(np.max(y_prob[bin_mask], axis=1))
            if bin_confidence > bin_accuracy:
                oe += (bin_confidence - bin_accuracy) * bin_size / len(y_true)
    return oe

# 모델 1 (Baseline1)
model1 = create_baseline1_model()
history1, report1, y_pred1, y_true_classes = train_and_evaluate_model(model1, train_dataset, val_dataset, test_dataset,"baseline1")

# 모델 2 (VGG)
model2 = create_vgg_model()
history2, report2, y_pred2, _ = train_and_evaluate_model(model2, train_dataset, val_dataset, test_dataset,"vgg")

# 모델 3 (DenseNet)
model3 = create_densenet_model()
history3, report3, y_pred3, _ = train_and_evaluate_model(model3, train_dataset, val_dataset, test_dataset,"densenet")

# 앙상블 예측
y_pred_ensemble = (y_pred1 + y_pred2 + y_pred3) / 3
y_pred_classes_ensemble = np.argmax(y_pred_ensemble, axis=1)

# 앙상블 분류 보고서 생성
report_ensemble = classification_report(y_true_classes, y_pred_classes_ensemble, target_names=class_names, output_dict=True)
accuracy_ensemble = report_ensemble['accuracy']
recall_ensemble = report_ensemble['weighted avg']['recall']
precision_ensemble = report_ensemble['weighted avg']['precision']
f1_score_ensemble = report_ensemble['weighted avg']['f1-score']

print(f"Ensemble Accuracy: {accuracy_ensemble}")
print(f"Ensemble Recall: {recall_ensemble}")
print(f"Ensemble Precision: {precision_ensemble}")
print(f"Ensemble F1-score: {f1_score_ensemble}")

# ECE와 OE 계산
ece_ensemble = calculate_ece(y_true_classes, y_pred_ensemble)
oe_ensemble = calculate_oe(y_true_classes, y_pred_ensemble)

print(f"Ensemble ECE: {ece_ensemble}")
print(f"Ensemble OE: {oe_ensemble}")

# 학습 과정 시각화
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history1.history['loss'], label='Baseline1 Train Loss')
plt.plot(history1.history['val_loss'], label='Baseline1 Valid Loss')
plt.plot(history2.history['loss'], label='VGG-like Train Loss')
plt.plot(history2.history['val_loss'], label='VGG-like Valid Loss')
plt.plot(history3.history['loss'], label='DenseNet-like Train Loss')
plt.plot(history3.history['val_loss'], label='DenseNet-like Valid Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history1.history['accuracy'], label='Baseline1 Train Accuracy')
plt.plot(history1.history['val_accuracy'], label='Baseline1 Valid Accuracy')
plt.plot(history2.history['accuracy'], label='VGG-like Train Accuracy')
plt.plot(history2.history['val_accuracy'], label='VGG-like Valid Accuracy')
plt.plot(history3.history['accuracy'], label='DenseNet-like Train Accuracy')
plt.plot(history3.history['val_accuracy'], label='DenseNet-like Valid Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# Epoch 1/100
# 2024-05-25 22:12:41.425875: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2024-05-25 22:12:41.715336: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8101
# 2024-05-25 22:12:42.097219: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
#  27/153 [====>.........................] - ETA: 0s - loss: 0.5195 - accuracy: 0.8113
# 2024-05-25 22:12:42.318025: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2024-05-25 22:12:42.347053: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 153/153 [==============================] - 2s 3ms/step - loss: 0.4649 - accuracy: 0.8187 - val_loss: 0.4899 - val_accuracy: 0.8113
# Epoch 2/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3701 - accuracy: 0.8480 - val_loss: 0.3577 - val_accuracy: 0.8623
# Epoch 3/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.3072 - accuracy: 0.8750 - val_loss: 0.3055 - val_accuracy: 0.8758
# Epoch 4/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.9017 - val_loss: 0.3191 - val_accuracy: 0.8734
# Epoch 5/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.2178 - accuracy: 0.9135 - val_loss: 0.3618 - val_accuracy: 0.8795
# Epoch 6/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.1795 - accuracy: 0.9301 - val_loss: 0.3958 - val_accuracy: 0.8740
# Epoch 7/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.1675 - accuracy: 0.9334 - val_loss: 0.4273 - val_accuracy: 0.8808
# Epoch 8/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.1365 - accuracy: 0.9453 - val_loss: 0.4380 - val_accuracy: 0.8937
# Epoch 9/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.1295 - accuracy: 0.9473 - val_loss: 0.3146 - val_accuracy: 0.9084
# Epoch 10/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.1313 - accuracy: 0.9502 - val_loss: 0.3493 - val_accuracy: 0.9029
# Epoch 11/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.9637 - val_loss: 0.5396 - val_accuracy: 0.8758
# Epoch 12/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0983 - accuracy: 0.9609 - val_loss: 0.5507 - val_accuracy: 0.8912
# Epoch 13/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0801 - accuracy: 0.9672 - val_loss: 0.6554 - val_accuracy: 0.8820
# Epoch 14/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9717 - val_loss: 0.3969 - val_accuracy: 0.9133
# Epoch 15/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0492 - accuracy: 0.9797 - val_loss: 0.3960 - val_accuracy: 0.9096
# Epoch 16/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0426 - accuracy: 0.9828 - val_loss: 0.4152 - val_accuracy: 0.9121
# Epoch 17/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0396 - accuracy: 0.9838 - val_loss: 0.4359 - val_accuracy: 0.9127
# Epoch 18/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0371 - accuracy: 0.9855 - val_loss: 0.4553 - val_accuracy: 0.9140
# Epoch 19/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9863 - val_loss: 0.4757 - val_accuracy: 0.9152
# Epoch 20/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 0.9865 - val_loss: 0.4944 - val_accuracy: 0.9133
# Epoch 21/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0316 - accuracy: 0.9871 - val_loss: 0.5131 - val_accuracy: 0.9140
# Epoch 22/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.9873 - val_loss: 0.5331 - val_accuracy: 0.9140
# Epoch 23/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0289 - accuracy: 0.9881 - val_loss: 0.5533 - val_accuracy: 0.9140
# Epoch 24/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9887 - val_loss: 0.5586 - val_accuracy: 0.9133
# Epoch 25/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9889 - val_loss: 0.5625 - val_accuracy: 0.9140
# Epoch 26/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 0.9889 - val_loss: 0.5658 - val_accuracy: 0.9140
# Epoch 27/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 0.9889 - val_loss: 0.5687 - val_accuracy: 0.9140
# Epoch 28/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 0.9891 - val_loss: 0.5717 - val_accuracy: 0.9140
# Epoch 29/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 0.9889 - val_loss: 0.5746 - val_accuracy: 0.9127
# Epoch 30/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9893 - val_loss: 0.5776 - val_accuracy: 0.9133
# Epoch 31/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 0.9896 - val_loss: 0.5806 - val_accuracy: 0.9127
# Epoch 32/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 0.9898 - val_loss: 0.5838 - val_accuracy: 0.9127
# Epoch 33/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 0.9898 - val_loss: 0.5872 - val_accuracy: 0.9109
# Epoch 34/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 0.9902 - val_loss: 0.5905 - val_accuracy: 0.9109
# Epoch 35/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0244 - accuracy: 0.9906 - val_loss: 0.5940 - val_accuracy: 0.9109
# Epoch 36/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9906 - val_loss: 0.5977 - val_accuracy: 0.9115
# Epoch 37/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0239 - accuracy: 0.9906 - val_loss: 0.6016 - val_accuracy: 0.9115
# Epoch 38/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0237 - accuracy: 0.9908 - val_loss: 0.6056 - val_accuracy: 0.9115
# Epoch 39/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 0.9908 - val_loss: 0.6095 - val_accuracy: 0.9121
# Epoch 40/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 0.9910 - val_loss: 0.6137 - val_accuracy: 0.9121
# Epoch 41/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 0.9910 - val_loss: 0.6180 - val_accuracy: 0.9121
# Epoch 42/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 0.9912 - val_loss: 0.6227 - val_accuracy: 0.9121
# Epoch 43/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 0.9912 - val_loss: 0.6271 - val_accuracy: 0.9121
# Epoch 44/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0221 - accuracy: 0.9912 - val_loss: 0.6319 - val_accuracy: 0.9121
# Epoch 45/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.9914 - val_loss: 0.6367 - val_accuracy: 0.9121
# Epoch 46/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 0.9916 - val_loss: 0.6418 - val_accuracy: 0.9127
# Epoch 47/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 0.9918 - val_loss: 0.6468 - val_accuracy: 0.9127
# Epoch 48/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 0.9918 - val_loss: 0.6519 - val_accuracy: 0.9133
# Epoch 49/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 0.9920 - val_loss: 0.6575 - val_accuracy: 0.9133
# Epoch 50/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 0.9920 - val_loss: 0.6626 - val_accuracy: 0.9133
# Epoch 51/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9920 - val_loss: 0.6686 - val_accuracy: 0.9133
# Epoch 52/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0199 - accuracy: 0.9920 - val_loss: 0.6741 - val_accuracy: 0.9133
# Epoch 53/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 0.9922 - val_loss: 0.6801 - val_accuracy: 0.9133
# Epoch 54/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 0.9922 - val_loss: 0.6860 - val_accuracy: 0.9133
# Epoch 55/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 0.9922 - val_loss: 0.6916 - val_accuracy: 0.9133
# Epoch 56/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 0.9922 - val_loss: 0.6977 - val_accuracy: 0.9133
# Epoch 57/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9922 - val_loss: 0.7040 - val_accuracy: 0.9133
# Epoch 58/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9924 - val_loss: 0.7101 - val_accuracy: 0.9133
# Epoch 59/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9924 - val_loss: 0.7168 - val_accuracy: 0.9133
# Epoch 60/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9926 - val_loss: 0.7231 - val_accuracy: 0.9133
# Epoch 61/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.9930 - val_loss: 0.7294 - val_accuracy: 0.9133
# Epoch 62/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9936 - val_loss: 0.7361 - val_accuracy: 0.9133
# Epoch 63/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9939 - val_loss: 0.7427 - val_accuracy: 0.9133
# Epoch 64/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 0.9939 - val_loss: 0.7492 - val_accuracy: 0.9121
# Epoch 65/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 0.9939 - val_loss: 0.7563 - val_accuracy: 0.9121
# Epoch 66/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.9939 - val_loss: 0.7632 - val_accuracy: 0.9121
# Epoch 67/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.9939 - val_loss: 0.7701 - val_accuracy: 0.9121
# Epoch 68/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.9939 - val_loss: 0.7776 - val_accuracy: 0.9127
# Epoch 69/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.9939 - val_loss: 0.7847 - val_accuracy: 0.9127
# Epoch 70/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.9941 - val_loss: 0.7921 - val_accuracy: 0.9121
# Epoch 71/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 0.9945 - val_loss: 0.7997 - val_accuracy: 0.9121
# Epoch 72/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9947 - val_loss: 0.8074 - val_accuracy: 0.9121
# Epoch 73/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 0.9949 - val_loss: 0.8147 - val_accuracy: 0.9121
# Epoch 74/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9951 - val_loss: 0.8228 - val_accuracy: 0.9121
# Epoch 75/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.8310 - val_accuracy: 0.9127
# Epoch 76/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 0.9951 - val_loss: 0.8389 - val_accuracy: 0.9127
# Epoch 77/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9953 - val_loss: 0.8468 - val_accuracy: 0.9127
# Epoch 78/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.8551 - val_accuracy: 0.9121
# Epoch 79/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.8629 - val_accuracy: 0.9121
# Epoch 80/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.8714 - val_accuracy: 0.9121
# Epoch 81/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.8798 - val_accuracy: 0.9115
# Epoch 82/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.8880 - val_accuracy: 0.9121
# Epoch 83/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.8961 - val_accuracy: 0.9127
# Epoch 84/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.9052 - val_accuracy: 0.9121
# Epoch 85/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.9133 - val_accuracy: 0.9127
# Epoch 86/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.9211 - val_accuracy: 0.9127
# Epoch 87/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.9298 - val_accuracy: 0.9127
# Epoch 88/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.9382 - val_accuracy: 0.9133
# Epoch 89/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.9466 - val_accuracy: 0.9133
# Epoch 90/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 0.9963 - val_loss: 0.9553 - val_accuracy: 0.9127
# Epoch 91/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.9633 - val_accuracy: 0.9121
# Epoch 92/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0106 - accuracy: 0.9967 - val_loss: 0.9721 - val_accuracy: 0.9127
# Epoch 93/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.9804 - val_accuracy: 0.9121
# Epoch 94/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.9890 - val_accuracy: 0.9127
# Epoch 95/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.9982 - val_accuracy: 0.9121
# Epoch 96/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 0.9967 - val_loss: 1.0065 - val_accuracy: 0.9121
# Epoch 97/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 1.0150 - val_accuracy: 0.9127
# Epoch 98/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 1.0235 - val_accuracy: 0.9121
# Epoch 99/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 0.9969 - val_loss: 1.0321 - val_accuracy: 0.9121
# Epoch 100/100
# 153/153 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 0.9969 - val_loss: 1.0410 - val_accuracy: 0.9121
# 51/51 [==============================] - 0s 1ms/step - loss: 0.3226 - accuracy: 0.8654
# Test loss: 0.32255110144615173
# Test accuracy: 0.8653964400291443
# Epoch 1/100
# 153/153 [==============================] - 1s 4ms/step - loss: 0.7014 - accuracy: 0.7972 - val_loss: 0.4335 - val_accuracy: 0.8064
# Epoch 2/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3928 - accuracy: 0.8316 - val_loss: 0.3247 - val_accuracy: 0.8593
# Epoch 3/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.3228 - accuracy: 0.8674 - val_loss: 0.2983 - val_accuracy: 0.8980
# Epoch 4/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.2523 - accuracy: 0.8978 - val_loss: 0.2539 - val_accuracy: 0.9023
# Epoch 5/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.2252 - accuracy: 0.9094 - val_loss: 0.2447 - val_accuracy: 0.9035
# Epoch 6/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1911 - accuracy: 0.9234 - val_loss: 0.2607 - val_accuracy: 0.9146
# Epoch 7/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1550 - accuracy: 0.9392 - val_loss: 0.2641 - val_accuracy: 0.9293
# Epoch 8/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1411 - accuracy: 0.9437 - val_loss: 0.2299 - val_accuracy: 0.9256
# Epoch 9/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1284 - accuracy: 0.9492 - val_loss: 0.2657 - val_accuracy: 0.9219
# Epoch 10/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1283 - accuracy: 0.9476 - val_loss: 0.3624 - val_accuracy: 0.9121
# Epoch 11/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1198 - accuracy: 0.9539 - val_loss: 0.2944 - val_accuracy: 0.9096
# Epoch 12/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1112 - accuracy: 0.9570 - val_loss: 0.4462 - val_accuracy: 0.9219
# Epoch 13/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.1085 - accuracy: 0.9582 - val_loss: 0.2779 - val_accuracy: 0.9035
# Epoch 14/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0914 - accuracy: 0.9611 - val_loss: 0.2390 - val_accuracy: 0.9256
# Epoch 15/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0787 - accuracy: 0.9711 - val_loss: 0.5537 - val_accuracy: 0.9078
# Epoch 16/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0738 - accuracy: 0.9709 - val_loss: 0.3748 - val_accuracy: 0.9029
# Epoch 17/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0603 - accuracy: 0.9750 - val_loss: 0.2999 - val_accuracy: 0.9127
# Epoch 18/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0624 - accuracy: 0.9752 - val_loss: 0.3152 - val_accuracy: 0.9213
# Epoch 19/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0409 - accuracy: 0.9859 - val_loss: 0.3017 - val_accuracy: 0.9238
# Epoch 20/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0172 - accuracy: 0.9947 - val_loss: 0.3810 - val_accuracy: 0.9213
# Epoch 21/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.4495 - val_accuracy: 0.9201
# Epoch 22/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.5049 - val_accuracy: 0.9213
# Epoch 23/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.5472 - val_accuracy: 0.9213
# Epoch 24/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.5794 - val_accuracy: 0.9207
# Epoch 25/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 0.9982 - val_loss: 0.6114 - val_accuracy: 0.9201
# Epoch 26/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.6417 - val_accuracy: 0.9189
# Epoch 27/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.9984 - val_loss: 0.6653 - val_accuracy: 0.9201
# Epoch 28/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.6834 - val_accuracy: 0.9201
# Epoch 29/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.6857 - val_accuracy: 0.9201
# Epoch 30/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.6881 - val_accuracy: 0.9201
# Epoch 31/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.6909 - val_accuracy: 0.9207
# Epoch 32/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.6940 - val_accuracy: 0.9207
# Epoch 33/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.6972 - val_accuracy: 0.9207
# Epoch 34/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.7005 - val_accuracy: 0.9207
# Epoch 35/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.7045 - val_accuracy: 0.9207
# Epoch 36/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.7085 - val_accuracy: 0.9207
# Epoch 37/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.7126 - val_accuracy: 0.9207
# Epoch 38/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.7173 - val_accuracy: 0.9207
# Epoch 39/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.7218 - val_accuracy: 0.9207
# Epoch 40/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.7273 - val_accuracy: 0.9207
# Epoch 41/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.7325 - val_accuracy: 0.9207
# Epoch 42/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.7385 - val_accuracy: 0.9207
# Epoch 43/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.7436 - val_accuracy: 0.9207
# Epoch 44/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.7497 - val_accuracy: 0.9213
# Epoch 45/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.7560 - val_accuracy: 0.9213
# Epoch 46/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.7613 - val_accuracy: 0.9213
# Epoch 47/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.7685 - val_accuracy: 0.9213
# Epoch 48/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 0.7738 - val_accuracy: 0.9213
# Epoch 49/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.7811 - val_accuracy: 0.9207
# Epoch 50/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.7876 - val_accuracy: 0.9207
# Epoch 51/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.7943 - val_accuracy: 0.9213
# Epoch 52/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.7992 - val_accuracy: 0.9213
# Epoch 53/100
# 153/153 [==============================] - 1s 3ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.8068 - val_accuracy: 0.9213
# Epoch 54/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.8139 - val_accuracy: 0.9213
# Epoch 55/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.8206 - val_accuracy: 0.9213
# Epoch 56/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.8284 - val_accuracy: 0.9207
# Epoch 57/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.8346 - val_accuracy: 0.9213
# Epoch 58/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.8439 - val_accuracy: 0.9207
# Epoch 59/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.8485 - val_accuracy: 0.9213
# Epoch 60/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.8571 - val_accuracy: 0.9213
# Epoch 61/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.8664 - val_accuracy: 0.9207
# Epoch 62/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.8741 - val_accuracy: 0.9207
# Epoch 63/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.8808 - val_accuracy: 0.9213
# Epoch 64/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.8897 - val_accuracy: 0.9213
# Epoch 65/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.8992 - val_accuracy: 0.9213
# Epoch 66/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.9060 - val_accuracy: 0.9213
# Epoch 67/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.9154 - val_accuracy: 0.9213
# Epoch 68/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9252 - val_accuracy: 0.9213
# Epoch 69/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9331 - val_accuracy: 0.9207
# Epoch 70/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9411 - val_accuracy: 0.9213
# Epoch 71/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.9461 - val_accuracy: 0.9213
# Epoch 72/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9586 - val_accuracy: 0.9207
# Epoch 73/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9693 - val_accuracy: 0.9207
# Epoch 74/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9804 - val_accuracy: 0.9207
# Epoch 75/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9886 - val_accuracy: 0.9207
# Epoch 76/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.9973 - val_accuracy: 0.9207
# Epoch 77/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0094 - val_accuracy: 0.9207
# Epoch 78/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0159 - val_accuracy: 0.9207
# Epoch 79/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0283 - val_accuracy: 0.9207
# Epoch 80/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0395 - val_accuracy: 0.9207
# Epoch 81/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0507 - val_accuracy: 0.9207
# Epoch 82/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0600 - val_accuracy: 0.9207
# Epoch 83/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0725 - val_accuracy: 0.9207
# Epoch 84/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.0845 - val_accuracy: 0.9207
# Epoch 85/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0833 - val_accuracy: 0.9201
# Epoch 86/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.0953 - val_accuracy: 0.9207
# Epoch 87/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1105 - val_accuracy: 0.9207
# Epoch 88/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1239 - val_accuracy: 0.9207
# Epoch 89/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1376 - val_accuracy: 0.9207
# Epoch 90/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1482 - val_accuracy: 0.9207
# Epoch 91/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1583 - val_accuracy: 0.9201
# Epoch 92/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 1.1643 - val_accuracy: 0.9201
# Epoch 93/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1774 - val_accuracy: 0.9207
# Epoch 94/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.1897 - val_accuracy: 0.9201
# Epoch 95/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2029 - val_accuracy: 0.9201
# Epoch 96/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2152 - val_accuracy: 0.9201
# Epoch 97/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2259 - val_accuracy: 0.9201
# Epoch 98/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2400 - val_accuracy: 0.9201
# Epoch 99/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2546 - val_accuracy: 0.9201
# Epoch 100/100
# 153/153 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 1.2650 - val_accuracy: 0.9201
# 51/51 [==============================] - 0s 1ms/step - loss: 0.2779 - accuracy: 0.9189
# Test loss: 0.2779010832309723
# Test accuracy: 0.9188690781593323
# Epoch 1/100
# 153/153 [==============================] - 2s 9ms/step - loss: 0.4811 - accuracy: 0.8062 - val_loss: 0.5164 - val_accuracy: 0.7695
# Epoch 2/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.4309 - accuracy: 0.8216 - val_loss: 0.7943 - val_accuracy: 0.5507
# Epoch 3/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.3904 - accuracy: 0.8439 - val_loss: 0.4813 - val_accuracy: 0.8224
# Epoch 4/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.3500 - accuracy: 0.8601 - val_loss: 0.3589 - val_accuracy: 0.8574
# Epoch 5/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.3245 - accuracy: 0.8750 - val_loss: 0.3640 - val_accuracy: 0.8685
# Epoch 6/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.3002 - accuracy: 0.8836 - val_loss: 0.3388 - val_accuracy: 0.8783
# Epoch 7/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.2664 - accuracy: 0.8947 - val_loss: 0.6043 - val_accuracy: 0.8433
# Epoch 8/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.2439 - accuracy: 0.9004 - val_loss: 0.3559 - val_accuracy: 0.8697
# Epoch 9/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.2278 - accuracy: 0.9084 - val_loss: 0.2983 - val_accuracy: 0.8918
# Epoch 10/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1972 - accuracy: 0.9269 - val_loss: 0.6687 - val_accuracy: 0.7941
# Epoch 11/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1825 - accuracy: 0.9277 - val_loss: 0.3419 - val_accuracy: 0.8771
# Epoch 12/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1740 - accuracy: 0.9322 - val_loss: 0.3464 - val_accuracy: 0.8746
# Epoch 13/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1633 - accuracy: 0.9338 - val_loss: 0.2126 - val_accuracy: 0.9293
# Epoch 14/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1443 - accuracy: 0.9426 - val_loss: 0.3077 - val_accuracy: 0.9078
# Epoch 15/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1437 - accuracy: 0.9430 - val_loss: 0.2986 - val_accuracy: 0.8986
# Epoch 16/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1323 - accuracy: 0.9465 - val_loss: 0.4387 - val_accuracy: 0.8992
# Epoch 17/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1391 - accuracy: 0.9439 - val_loss: 0.2493 - val_accuracy: 0.9176
# Epoch 18/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1260 - accuracy: 0.9500 - val_loss: 0.4223 - val_accuracy: 0.8881
# Epoch 19/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1156 - accuracy: 0.9523 - val_loss: 0.2119 - val_accuracy: 0.9250
# Epoch 20/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1204 - accuracy: 0.9519 - val_loss: 0.3053 - val_accuracy: 0.8955
# Epoch 21/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0997 - accuracy: 0.9592 - val_loss: 0.2385 - val_accuracy: 0.9342
# Epoch 22/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1034 - accuracy: 0.9576 - val_loss: 0.2630 - val_accuracy: 0.9281
# Epoch 23/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0908 - accuracy: 0.9621 - val_loss: 0.5563 - val_accuracy: 0.9041
# Epoch 24/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1005 - accuracy: 0.9596 - val_loss: 0.4267 - val_accuracy: 0.8980
# Epoch 25/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0941 - accuracy: 0.9619 - val_loss: 0.5832 - val_accuracy: 0.8924
# Epoch 26/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0827 - accuracy: 0.9650 - val_loss: 0.2032 - val_accuracy: 0.9299
# Epoch 27/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.1017 - accuracy: 0.9600 - val_loss: 0.2768 - val_accuracy: 0.9121
# Epoch 28/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0832 - accuracy: 0.9666 - val_loss: 0.2029 - val_accuracy: 0.9373
# Epoch 29/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0920 - accuracy: 0.9627 - val_loss: 0.3245 - val_accuracy: 0.9053
# Epoch 30/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0838 - accuracy: 0.9668 - val_loss: 0.2546 - val_accuracy: 0.9275
# Epoch 31/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0785 - accuracy: 0.9666 - val_loss: 0.5082 - val_accuracy: 0.9072
# Epoch 32/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0780 - accuracy: 0.9674 - val_loss: 0.4494 - val_accuracy: 0.8955
# Epoch 33/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0792 - accuracy: 0.9670 - val_loss: 0.2987 - val_accuracy: 0.9226
# Epoch 34/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0721 - accuracy: 0.9689 - val_loss: 0.8793 - val_accuracy: 0.8334
# Epoch 35/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0857 - accuracy: 0.9658 - val_loss: 1.0075 - val_accuracy: 0.8685
# Epoch 36/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0782 - accuracy: 0.9682 - val_loss: 0.2148 - val_accuracy: 0.9404
# Epoch 37/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0627 - accuracy: 0.9732 - val_loss: 0.2091 - val_accuracy: 0.9471
# Epoch 38/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0846 - accuracy: 0.9664 - val_loss: 0.2733 - val_accuracy: 0.9342
# Epoch 39/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0563 - accuracy: 0.9754 - val_loss: 0.2100 - val_accuracy: 0.9465
# Epoch 40/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0507 - accuracy: 0.9775 - val_loss: 0.2066 - val_accuracy: 0.9471
# Epoch 41/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0485 - accuracy: 0.9779 - val_loss: 0.2106 - val_accuracy: 0.9484
# Epoch 42/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0469 - accuracy: 0.9781 - val_loss: 0.2187 - val_accuracy: 0.9490
# Epoch 43/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0455 - accuracy: 0.9785 - val_loss: 0.2277 - val_accuracy: 0.9490
# Epoch 44/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0443 - accuracy: 0.9785 - val_loss: 0.2316 - val_accuracy: 0.9496
# Epoch 45/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0431 - accuracy: 0.9795 - val_loss: 0.2383 - val_accuracy: 0.9490
# Epoch 46/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0416 - accuracy: 0.9799 - val_loss: 0.2485 - val_accuracy: 0.9478
# Epoch 47/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0404 - accuracy: 0.9816 - val_loss: 0.2610 - val_accuracy: 0.9465
# Epoch 48/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0389 - accuracy: 0.9822 - val_loss: 0.2721 - val_accuracy: 0.9465
# Epoch 49/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0371 - accuracy: 0.9828 - val_loss: 0.2742 - val_accuracy: 0.9465
# Epoch 50/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0365 - accuracy: 0.9834 - val_loss: 0.2772 - val_accuracy: 0.9465
# Epoch 51/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0362 - accuracy: 0.9836 - val_loss: 0.2800 - val_accuracy: 0.9453
# Epoch 52/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0359 - accuracy: 0.9838 - val_loss: 0.2827 - val_accuracy: 0.9453
# Epoch 53/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0357 - accuracy: 0.9838 - val_loss: 0.2850 - val_accuracy: 0.9453
# Epoch 54/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0354 - accuracy: 0.9842 - val_loss: 0.2873 - val_accuracy: 0.9453
# Epoch 55/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0352 - accuracy: 0.9842 - val_loss: 0.2897 - val_accuracy: 0.9441
# Epoch 56/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0350 - accuracy: 0.9844 - val_loss: 0.2920 - val_accuracy: 0.9441
# Epoch 57/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0347 - accuracy: 0.9844 - val_loss: 0.2944 - val_accuracy: 0.9447
# Epoch 58/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0345 - accuracy: 0.9846 - val_loss: 0.2969 - val_accuracy: 0.9447
# Epoch 59/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0342 - accuracy: 0.9842 - val_loss: 0.2995 - val_accuracy: 0.9447
# Epoch 60/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0339 - accuracy: 0.9846 - val_loss: 0.3017 - val_accuracy: 0.9447
# Epoch 61/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0336 - accuracy: 0.9846 - val_loss: 0.3043 - val_accuracy: 0.9447
# Epoch 62/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0334 - accuracy: 0.9846 - val_loss: 0.3070 - val_accuracy: 0.9441
# Epoch 63/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0331 - accuracy: 0.9848 - val_loss: 0.3098 - val_accuracy: 0.9435
# Epoch 64/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0328 - accuracy: 0.9852 - val_loss: 0.3125 - val_accuracy: 0.9441
# Epoch 65/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0325 - accuracy: 0.9855 - val_loss: 0.3152 - val_accuracy: 0.9428
# Epoch 66/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0322 - accuracy: 0.9855 - val_loss: 0.3181 - val_accuracy: 0.9428
# Epoch 67/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0320 - accuracy: 0.9857 - val_loss: 0.3207 - val_accuracy: 0.9435
# Epoch 68/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0317 - accuracy: 0.9859 - val_loss: 0.3234 - val_accuracy: 0.9435
# Epoch 69/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0315 - accuracy: 0.9861 - val_loss: 0.3264 - val_accuracy: 0.9435
# Epoch 70/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0312 - accuracy: 0.9859 - val_loss: 0.3297 - val_accuracy: 0.9441
# Epoch 71/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0309 - accuracy: 0.9861 - val_loss: 0.3329 - val_accuracy: 0.9441
# Epoch 72/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0307 - accuracy: 0.9861 - val_loss: 0.3360 - val_accuracy: 0.9447
# Epoch 73/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0304 - accuracy: 0.9861 - val_loss: 0.3395 - val_accuracy: 0.9447
# Epoch 74/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0302 - accuracy: 0.9865 - val_loss: 0.3426 - val_accuracy: 0.9435
# Epoch 75/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0299 - accuracy: 0.9865 - val_loss: 0.3464 - val_accuracy: 0.9435
# Epoch 76/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0296 - accuracy: 0.9867 - val_loss: 0.3496 - val_accuracy: 0.9428
# Epoch 77/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0294 - accuracy: 0.9869 - val_loss: 0.3537 - val_accuracy: 0.9428
# Epoch 78/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0291 - accuracy: 0.9871 - val_loss: 0.3576 - val_accuracy: 0.9428
# Epoch 79/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0288 - accuracy: 0.9873 - val_loss: 0.3613 - val_accuracy: 0.9428
# Epoch 80/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0286 - accuracy: 0.9873 - val_loss: 0.3657 - val_accuracy: 0.9428
# Epoch 81/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0283 - accuracy: 0.9873 - val_loss: 0.3702 - val_accuracy: 0.9428
# Epoch 82/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0280 - accuracy: 0.9873 - val_loss: 0.3735 - val_accuracy: 0.9422
# Epoch 83/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0277 - accuracy: 0.9875 - val_loss: 0.3777 - val_accuracy: 0.9416
# Epoch 84/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0274 - accuracy: 0.9877 - val_loss: 0.3811 - val_accuracy: 0.9416
# Epoch 85/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0271 - accuracy: 0.9881 - val_loss: 0.3851 - val_accuracy: 0.9428
# Epoch 86/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0268 - accuracy: 0.9883 - val_loss: 0.3893 - val_accuracy: 0.9428
# Epoch 87/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0265 - accuracy: 0.9879 - val_loss: 0.3931 - val_accuracy: 0.9428
# Epoch 88/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0262 - accuracy: 0.9881 - val_loss: 0.3975 - val_accuracy: 0.9416
# Epoch 89/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0259 - accuracy: 0.9883 - val_loss: 0.4021 - val_accuracy: 0.9404
# Epoch 90/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0256 - accuracy: 0.9885 - val_loss: 0.4064 - val_accuracy: 0.9398
# Epoch 91/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0253 - accuracy: 0.9889 - val_loss: 0.4109 - val_accuracy: 0.9398
# Epoch 92/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0250 - accuracy: 0.9893 - val_loss: 0.4153 - val_accuracy: 0.9398
# Epoch 93/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0248 - accuracy: 0.9896 - val_loss: 0.4199 - val_accuracy: 0.9392
# Epoch 94/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0245 - accuracy: 0.9902 - val_loss: 0.4245 - val_accuracy: 0.9385
# Epoch 95/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0242 - accuracy: 0.9902 - val_loss: 0.4293 - val_accuracy: 0.9385
# Epoch 96/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0239 - accuracy: 0.9902 - val_loss: 0.4341 - val_accuracy: 0.9385
# Epoch 97/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0237 - accuracy: 0.9904 - val_loss: 0.4386 - val_accuracy: 0.9385
# Epoch 98/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0234 - accuracy: 0.9904 - val_loss: 0.4437 - val_accuracy: 0.9379
# Epoch 99/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0232 - accuracy: 0.9904 - val_loss: 0.4482 - val_accuracy: 0.9379
# Epoch 100/100
# 153/153 [==============================] - 1s 7ms/step - loss: 0.0229 - accuracy: 0.9906 - val_loss: 0.4532 - val_accuracy: 0.9379
# 51/51 [==============================] - 0s 2ms/step - loss: 0.3055 - accuracy: 0.9146
# Test loss: 0.30547821521759033
# Test accuracy: 0.914566695690155
# Ensemble Accuracy: 0.9416103257529195
# Ensemble Recall: 0.9416103257529195
# Ensemble Precision: 0.9405884930432483
# Ensemble F1-score: 0.9396743894451145
# Ensemble ECE: 0.04551209653163878
# Ensemble OE: 0.0
